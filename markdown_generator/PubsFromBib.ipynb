# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "../cv/own-bib.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "../cv/own-bib.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'booktitle' from entry Troels2022: " Instant and global consistency ... "
# SUCESSFULLY PARSED 10.1145/3546932.3547015: " Code Smell Analysis in Cloned Java Variants: The Apo-Games C ... "
# SUCESSFULLY PARSED CORP: " Change-Oriented Repair Propagation  "
# WARNING Missing Expected Field 'booktitle' from entry Marchezan2022b: " Software product line scoping: ... "
# WARNING Missing Expected Field 'booktitle' from entry Marchezan2022c: " Generating repairs for inconsi ... "
# SUCESSFULLY PARSED Marchezan2021: " {SPLReePlan - Automated Support for Software Product Line Re ... "
# SUCESSFULLY PARSED 10.1145/3382026.3425767: " {Enhancing the Feature Retrieval Process with Scoping and To ... "
# WARNING Missing Expected Field 'booktitle' from entry Iung2020: " Systematic mapping study on do ... "
# SUCESSFULLY PARSED 8870160: " Thoth: A Web-based Tool to Support Systematic Reviews  "
# WARNING Missing Expected Field 'booktitle' from entry Marchezan2019b: " {PAxSPL: A feature retrieval p ... "
# SUCESSFULLY PARSED 10.1145/3194133.3194136: " A Systematic Literature Review of UML-Based Domain-Specific  ... "
# WARNING Missing Expected Field 'booktitle' from entry Bernardino2017: " Systematic mapping study on MB ... "
# SUCESSFULLY PARSED marchezan2022paxspl: " {PAxSPL: A Framework for Aiding SPL Reengineering Planning}  "
# SUCESSFULLY PARSED rodrigues2022plets: " {PLeTs: A Software Product Line for Testing Tools}  "
# SUCESSFULLY PARSED marchezan2017towards: " Towards a generic process for spl re-engineering  "
# SUCESSFULLY PARSED carbonelli2018analyzing: " Analyzing the Impact of the Search Phase in a Systematic Map ... "
# SUCESSFULLY PARSED marchezan2019customizable: " A customizable SPL scoping process for SPL reengineering  "
# SUCESSFULLY PARSED EASE: " Do Developers Benefit from Recommendations When Repairing In ... "
# SUCESSFULLY PARSED SEIP: " Fulfilling Industrial Needs for Consistency Among Engineerin ... "
# WARNING Missing Expected Field 'booktitle' from entry Herac2023: " A flexible operation-based inf ... "
# SUCESSFULLY PARSED homolka2024don: " {“Don’t Touch my Model!” Towards Managing Model History and  ... "
# WARNING Missing Expected Field 'booktitle' from entry MAYRDORN2024: " Actionable light-weight proces ... "
# SUCESSFULLY PARSED Marchezan2024: " Exploring Dependencies Among Inconsistencies to Enhance the  ... "
# WARNING Missing Expected Field 'booktitle' from entry Herac2024: " Conflict-based Change Awarenes ... "
# SUCESSFULLY PARSED Assunção2024: " Contemporary Software Modernization: Perspectives and Challe ... "
# SUCESSFULLY PARSED Marchezan2024GenAi: " Model-based Maintenance and Evolution with GenAI: A Look int ... "
# SUCESSFULLY PARSED homolkahappened: " {“What Happened to my Models?” History-Aware Co-Existence an ... "
# WARNING Missing Expected Field 'booktitle' from entry Assuncao2024: " Contemporary Software Moderniz ... "
# SUCESSFULLY PARSED Marchezan2024Tool: " A Tool for Collaborative Consistency Checking During Modelin ... "
# SUCESSFULLY PARSED homolka2025going: " Going from the Past back to the Future: Incrementally Recons ... "
# WARNING Missing Expected Field 'booktitle' from entry homolka2026really: " {“What really happened to my m ... "
# SUCESSFULLY PARSED Desai2025: " {PrioTestCI: Efficient Test Case Prioritization in GitHub Wo ... "
# WARNING Missing Expected Field 'booktitle' from entry marchezan2026dependency: " {Dependency-aware model repair ... "
# SUCESSFULLY PARSED Marchezan2026Kamino: " {Automated Type-IV Clone Generation via LLMs and Determinist ... "
# WARNING Missing Expected Field 'booktitle' from entry Marchezan2026NeoModeling: " {NeoModeling Framework: Levera ... "
# SUCESSFULLY PARSED Troels2022: " Instant and global consistency checking during collaborative ... "
# WARNING Missing Expected Field 'journal' from entry 10.1145/3546932.3547015: " Code Smell Analysis in Cloned  ... "
# WARNING Missing Expected Field 'journal' from entry CORP: " Change-Oriented Repair Propaga ... "
# SUCESSFULLY PARSED Marchezan2022b: " Software product line scoping: A systematic literature revie ... "
# SUCESSFULLY PARSED Marchezan2022c: " Generating repairs for inconsistent models  "
# WARNING Missing Expected Field 'journal' from entry Marchezan2021: " {SPLReePlan - Automated Suppor ... "
# WARNING Missing Expected Field 'journal' from entry 10.1145/3382026.3425767: " {Enhancing the Feature Retriev ... "
# SUCESSFULLY PARSED Iung2020: " Systematic mapping study on domain-specific language develop ... "
# WARNING Missing Expected Field 'journal' from entry 8870160: " Thoth: A Web-based Tool to Sup ... "
# SUCESSFULLY PARSED Marchezan2019b: " {PAxSPL: A feature retrieval process for software product li ... "
# WARNING Missing Expected Field 'journal' from entry 10.1145/3194133.3194136: " A Systematic Literature Review ... "
# SUCESSFULLY PARSED Bernardino2017: " Systematic mapping study on MBT: Tools and models  "
# WARNING Missing Expected Field 'journal' from entry marchezan2022paxspl: " {PAxSPL: A Framework for Aidin ... "
# WARNING Missing Expected Field 'journal' from entry rodrigues2022plets: " {PLeTs: A Software Product Lin ... "
# WARNING Missing Expected Field 'journal' from entry marchezan2017towards: " Towards a generic process for  ... "
# WARNING Missing Expected Field 'journal' from entry carbonelli2018analyzing: " Analyzing the Impact of the Se ... "
# WARNING Missing Expected Field 'journal' from entry marchezan2019customizable: " A customizable SPL scoping pro ... "
# WARNING Missing Expected Field 'journal' from entry EASE: " Do Developers Benefit from Rec ... "
# WARNING Missing Expected Field 'journal' from entry SEIP: " Fulfilling Industrial Needs fo ... "
# SUCESSFULLY PARSED Herac2023: " A flexible operation-based infrastructure for collaborative  ... "
# WARNING Missing Expected Field 'journal' from entry homolka2024don: " {“Don’t Touch my Model!” Towar ... "
# SUCESSFULLY PARSED MAYRDORN2024: " Actionable light-weight process guidance  "
# WARNING Missing Expected Field 'journal' from entry Marchezan2024: " Exploring Dependencies Among I ... "
# SUCESSFULLY PARSED Herac2024: " Conflict-based Change Awareness for Collaborative Model-driv ... "
# WARNING Missing Expected Field 'journal' from entry Assunção2024: " Contemporary Software Moderniz ... "
# WARNING Missing Expected Field 'journal' from entry Marchezan2024GenAi: " Model-based Maintenance and Ev ... "
# WARNING Missing Expected Field 'journal' from entry homolkahappened: " {“What Happened to my Models?” ... "
# SUCESSFULLY PARSED Assuncao2024: " Contemporary Software Modernization: Strategies, Driving For ... "
# WARNING Missing Expected Field 'journal' from entry Marchezan2024Tool: " A Tool for Collaborative Consi ... "
# WARNING Missing Expected Field 'journal' from entry homolka2025going: " Going from the Past back to th ... "
# SUCESSFULLY PARSED homolka2026really: " {“What really happened to my models?” Extending co-evolution ... "
# WARNING Missing Expected Field 'journal' from entry Desai2025: " {PrioTestCI: Efficient Test Ca ... "
# SUCESSFULLY PARSED marchezan2026dependency: " {Dependency-aware model repair: prioritizing repairs through ... "
# WARNING Missing Expected Field 'journal' from entry Marchezan2026Kamino: " {Automated Type-IV Clone Gener ... "
# SUCESSFULLY PARSED Marchezan2026NeoModeling: " {NeoModeling Framework: Leveraging Graph-Based Persistence f ... "
